# %%
# Install required packages (auto-skipped if already installed)
import importlib
if importlib.util.find_spec('qiskit') is None:
    # !pip install -q qiskit qiskit-aer qiskit-ibm-runtime pylatexenc
else:
    print("\u2713 Packages already installed")

# To run on real quantum hardware, uncomment and fill in your credentials:
# from qiskit_ibm_runtime import QiskitRuntimeService
# QiskitRuntimeService.save_account(
#     token="<your-api-key>",
#     instance="<your-crn>",
#     overwrite=True
# )

# %% [markdown]
# # Qiskit Serverlessへのコードの移植
#
# import Tabs from '@theme/Tabs';
# import TabItem from '@theme/TabItem';
#
#
#
# 以下の例では、既存のコードをQiskit Serverlessを活用するように移植する方法を示します。
# > **Note:** 以下のコードは、認証情報が保存済みであることを前提としています。まだ保存していない場合は、[IBM Cloudアカウントのセットアップ](/guides/cloud-setup-untrusted)の手順に従って、APIキーで認証を行ってください。
#
# ## 実験のアップデート
# <Tabs>
#   <TabItem value="LocalExperiment" label="ローカル実験">
